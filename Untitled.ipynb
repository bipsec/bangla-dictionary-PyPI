# %%
import pandas as pd

# %%
path = "/home/bip/PycharmProjects/pythonProject/Dictionary/data/"

# %%
df = pd.read_excel(path + "demo_data.xlsx")

# %%
df.columns
# Out:
# Index(['                                                                                         ',
#        'মূলশব্দ', 'অভিন্ন বানান ', 'উচ্চারণ', 'অর্থ', 'পদ', 'IPA [B]',
#        'ভাষা বিষয়ক', 'বিষয়-নির্দেশক', 'বাক্য', 'উৎস', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'PoS',
#        'ভাষা বিষয়ক.1', 'বিষয়-নির্দেশক.1'],
#       dtype='object')

# %%
def rename_columns(file):
    # read the Excel file
    data = pd.read_excel(file)
    data = data.drop(['Unnamed: 11',
        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'PoS',
        'ভাষা বিষয়ক.1', 'বিষয়-নির্দেশক.1'], axis=1,inplace=True)

    # rename all the columns with a new list of column name
    data.columns = 

    return data

# %%
import os
import pandas as pd

def rename_columns(filename, new_column_names):
    try:
        # Read the Excel file
        df = pd.read_excel(filename)
        
        # dropping null columns
        df = df.drop(['Unnamed: 11',
        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'PoS',
        'ভাষা বিষয়ক.1', 'বিষয়-নির্দেশক.1'], axis=1,inplace=True)

        # Rename the columns
#         df.columns = new_column_names

        return df
    except Exception as e:
        print(f"Error occurred while renaming columns: {e}")

# Example usage
filename = os.path.join(path+"demo_data.xlsx")
new_column_names = ["pageNo","word", "spelling", "pronunciation", "meaning",
                    "pos", "IPA [B]", "language", "class", "sentence", "source"]

renamed_df = rename_columns(filename, new_column_names)

if renamed_df is not None:
    print(renamed_df)
# Out:
# None

# %%
df.drop(['Unnamed: 11',
        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'PoS',
        'ভাষা বিষয়ক.1', 'বিষয়-নির্দেশক.1'], axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['                                                                                         ',
#        'মূলশব্দ', 'অভিন্ন বানান ', 'উচ্চারণ', 'অর্থ', 'পদ', 'IPA [B]',
#        'ভাষা বিষয়ক', 'বিষয়-নির্দেশক', 'বাক্য', 'উৎস'],
#       dtype='object')

# %%
df.columns = ["pageNo","word", "spelling", "pronunciation", "meaning",
                    "pos", "IPA [B]", "language", "class", "sentence", "source"]

# %%
df
# Out:
#     pageNo      word spelling pronunciation  \
# 0        ১         অ        ১             অ
# 1      NaN         অ        ২             অ
# 2      NaN         অ        ২             অ
# 3      NaN        অই        ১            ওই
# 4      NaN     অইরান        ১       ওইরান্‌
# ..     ...       ...      ...           ...
# 758    NaN  অক্ষিলোম        ১           NaN
# 759    NaN   অক্ষিপট        ১           NaN
# 760    NaN  অক্ষিপটল        ১           NaN
# 761    NaN  অক্ষিপুট        ১           NaN
# 762      ৭       NaN      NaN           NaN
#
#                                                meaning      pos  IPA [B]  \
# 0                          বাংলা স্বরবর্ণের প্রথম বর্ণ      NaN        ɔ
# 1                                    সম্বোধনসূচক অব্যয়  সম্বোঅব        ɔ
# 2                                               উপসর্গ       উপ        ɔ
# 3                       পদ্যে ছন্দের নির্দেশক স্বরবর্ণ      NaN     ɔ͡i̯
# 4                                                বিরান      NaN  ɔ͡i̯ran
# ..                                                 ...      ...      ...
# 758                                    চোখের পাতার লোম       বি      NaN
# 759  অক্ষিগোলকের পশ্চাদ্‌ভাগস্থ অতি সূক্ষ্ম ঝিল্লি ...       বি      NaN
# 760                                         চোখের পাতা       বি      NaN
# 761                                         চোখের পাতা       বি      NaN
# 762                                                NaN      NaN      NaN
#
#          language                   class         sentence  \
# 0             NaN                     NaN              NaN
# 1             NaN                     NaN  অ কপাল, অ মামুন
# 2             NaN         ব্যা. [ব্যাকরণ]              NaN
# 3    স. [সংস্কৃত]                     NaN              NaN
# 4     ফা. [ফারসি]                     NaN              NaN
# ..            ...                     ...              ...
# 758           NaN                     NaN              NaN
# 759           NaN  প্রাণি [প্রাণিবিজ্ঞান]              NaN
# 760           NaN                     NaN              NaN
# 761           NaN                     NaN              NaN
# 762           NaN                     NaN              NaN
#
#                      source
# 0                       NaN
# 1    ব্যবহারিক বাংলা অভিধান
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 758                     NaN
# 759                     NaN
# 760                     NaN
# 761                     NaN
# 762                     NaN
#
# [763 rows x 11 columns]
